# %% [markdown]
# <a href="https://colab.research.google.com/github/Fiarma/Data-Science-Projects/blob/fiarma/Projects_Computer_Vision_Detect_Cassava_Diseases%2C_Identify_and_Classify_Disease_Symptoms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Understanding**

# %%
# import libraries
import os
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

 #Data  extraction
import zipfile

# %%
# Create the directory if it doesn't exist
#os.makedirs(data_path, exist_ok=True)

# %%
# Data path
#data_path = 'Dataset/train'

# %%
## Dataset classes
#os.listdir(data_path)

# %%
# Label imbalance
data_path = [
    (p, os.path.join(data_path, p))
    for p in os.listdir(data_path)
]

# %%
# !pip install gdown
import gdown

# %%
#https://drive.google.com/file/d/1hK5GNa2SOfB5p_U_v9DBXWd3FAN0tDU9/view?usp=sharing

file_id = "1hK5GNa2SOfB5p_U_v9DBXWd3FAN0tDU9"
output_file = "agricultural-pests-image-dataset.zip"
gdown.download(id = file_id, output = output_file, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1hK5GNa2SOfB5p_U_v9DBXWd3FAN0tDU9
# From (redirected): https://drive.google.com/uc?id=1hK5GNa2SOfB5p_U_v9DBXWd3FAN0tDU9&confirm=t&uuid=05b07f88-36cc-44e4-be16-40dee5a981ea
# To: /content/agricultural-pests-image-dataset.zip
# 100%|██████████| 2.47G/2.47G [00:46<00:00, 52.7MB/s]
# 'agricultural-pests-image-dataset.zip'

# %%
# open zip file

with zipfile.ZipFile(output_file, 'r') as zip_ref:

    # extracts all content
    #zip_ref.extractall(output_file)
    DATA_PATH = os.path.splitext(output_file)[0]
    zip_ref.extractall(DATA_PATH)

# %%
# daaset classes

os.listdir(DATA_PATH)
# Out:
# ['random.txt',
#  'test.zip',
#  'sample_submission_file.csv',
#  'extraimages.zip',
#  'train.zip']

# %%
DATA_PATH
# Out:
# 'agricultural-pests-image-dataset'

# %%
data_path = [
    (p, os.path.join(DATA_PATH, p))
    for p in os.listdir(DATA_PATH)
]
