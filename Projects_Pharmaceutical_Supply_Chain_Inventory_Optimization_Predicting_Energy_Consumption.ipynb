# %% [markdown]
# <a href="https://colab.research.google.com/github/Fiarma/Data-Science-Projects/blob/fiarma/Projects_Pharmaceutical_Supply_Chain_Inventory_Optimization_Predicting_Energy_Consumption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Import Packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import  mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **2.  Data Exploration  and Preprocessing**

# %%
# !pip install gdown
import gdown

# %%
# load dataset

#https://drive.google.com/file/d/1Q_Dz6gpxGugfly1ZKaN1C-4hTA6at6oQ/view?usp=sharing

file_id = "1Q_Dz6gpxGugfly1ZKaN1C-4hTA6at6oQ"

output_file = 'dataset.csv'

gdown.download(id = file_id, output = output_file, quiet=False)

df = pd.read_csv(output_file)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Q_Dz6gpxGugfly1ZKaN1C-4hTA6at6oQ
# To: /content/dataset.csv
# 100%|██████████| 2.09M/2.09M [00:00<00:00, 57.0MB/s]

# %%
df.head()
# Out:
#   Product_ID  Shelf_Life_Days  Sales_2021  Sales_2022  Market_Trend_Factor  \
# 0  Product_1              277       602.6         545             0.906303
# 1  Product_2              343       359.4         345             0.972500
# 2  Product_3              291       983.0         915             1.026074
# 3  Product_4              298       789.4         751             0.911503
# 4  Product_5              260       326.8         430             1.052617
#
#   Compliance_Status  Supplier_ID Manufacturing_Location Product_Category  \
# 0         Compliant   Supplier_2             Location_B       Category_B
# 1         Compliant   Supplier_1             Location_C       Category_C
# 2     Non-compliant   Supplier_5             Location_C       Category_A
# 3         Compliant   Supplier_8             Location_C       Category_A
# 4         Compliant  Supplier_10             Location_A       Category_B
#
#    Safety_Stock_Days Storage_Location
# ...

# %%
# missing values
df.isnull().sum()
# Out:
# Product_ID                0
# Shelf_Life_Days           0
# Sales_2021                0
# Sales_2022                0
# Market_Trend_Factor       0
# Compliance_Status         0
# Supplier_ID               0
# Manufacturing_Location    0
# Product_Category          0
# Safety_Stock_Days         0
# Storage_Location          0
# dtype: int64

# %%
# check for duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        Shelf_Life_Days    Sales_2021    Sales_2022  Market_Trend_Factor  \
# count     19381.000000  19381.000000  19381.000000         19381.000000
# mean        301.737939    618.423250    618.798256             0.999851
# std          25.576353    239.313199    220.590729             0.257548
# min         260.000000     80.000000    234.000000             0.078110
# 25%         278.000000    429.000000    429.000000             0.823775
# 50%         302.000000    619.200000    621.000000             1.000239
# 75%         326.000000    811.200000    809.000000             1.175179
# max         344.000000   1155.400000    999.000000             1.909161
#
#        Safety_Stock_Days
# count       19381.000000
# mean           21.327073
# std             7.090764
# min             6.000000
# 25%            16.000000
# 50%            21.000000
# 75%            27.000000
# max            42.000000
